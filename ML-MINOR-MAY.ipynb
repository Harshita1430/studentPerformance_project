# %% [markdown]
# AIM:
#     To do exploration of data and to find out the factors on which the marks of students

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
study=pd.read_csv(r"StudentsPerformance.csv")

# %%
study.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
study.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
study.shape
# Out:
# (1000, 8)

# %%
study. dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
study.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
study.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
study["race/ethnicity"].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
study["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
study["lunch"].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
study.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
study["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
study["race/ethnicity"].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
study["parental level of education"]. value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
study["lunch"].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
study["test preparation course"]. value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
study.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
study["total"]=study["math score"] + study["reading score"]+ study ["writing score"]

# %%
study["average"]= study["total"]/3

# %%
study.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
# %matplotlib inline
study.groupby("gender").mean().plot(kind="bar")

# %%
study.groupby("race/ethnicity").mean().plot(kind="bar")

# %%
plt.subplot(142)
plt.title("Gender")
study["gender"]. value_counts().plot.pie()
plt.subplot(141)
plt.title("Race")
study["race/ethnicity"]. value_counts().plot.pie()
plt.subplot(143)
plt.title("Level of parental education")
study["parental level of education"].value_counts().plot.pie()

# %%
plt.subplot(141)
plt.title("lunch")
study["lunch"].value_counts().plot.pie()
plt.subplot(142)
plt.title("Preparation  Course")
study["test preparation course"].value_counts().plot.pie()

# %%
sns.lmplot("writing score","math score",data=study,hue="gender")

# %%
sns.lmplot("writing score","math score",data=study, hue="race/ethnicity")

# %%
sns.lmplot("writing score","math score",data=study, hue="parental level of education")

# %% [markdown]
# If the prental level of education is some high than the student might be weak in maths.

# %%
sns.lmplot("writing score","math score",data=study, hue="lunch")

# %%
sns.lmplot("writing score","math score",data=study, hue="test preparation course")

# %%
sns.lmplot("writing score","reading score",data=study,hue="gender")

# %%
sns.lmplot("writing score","reading score",data=study, hue="race/ethnicity")

# %%
sns.lmplot("writing score","reading score",data=study, hue="parental level of education")

# %%
sns.lmplot("writing score","reading score",data=study, hue="lunch")

# %%
sns.lmplot("writing score","reading score",data=study, hue="test preparation course")

# %%
sns.distplot(study["math score"])

# %%
sns.distplot(study["reading score"])

# %%
sns.distplot(study["writing score"])

# %%
sns.distplot(study["total"])

# %%
sns.distplot(study["average"])

# %%
sns.pairplot(study)

# %%
sns.barplot(study["gender"],study["average"])

# %%
sns.barplot(study["race/ethnicity"],study["average"])

# %%
sns.barplot(study["parental level of education"],study["average"])

# %%
sns.barplot(study["lunch"],study["average"])

# %%
sns.barplot(study["test preparation course"],study["average"])

# %%
study["math pass"]=np.where(study["math score"]  <50,"F","P")

# %%
study["writing pass"]=np.where(study["writing score"]<50,"F","P")

# %%
study["reading pass"]=np.where(study["reading score"]<50,"F","P")

# %%
study.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average math pass writing pass reading pass
# 0  72.666667         P            P            P
# ...

# %%
study["math pass"].value_counts()
# Out:
# P    865
# F    135
# Name: math pass, dtype: int64

# %%
study["writing pass"].value_counts()
# Out:
# P    886
# F    114
# Name: writing pass, dtype: int64

# %%
study["reading pass"].value_counts()
# Out:
# P    910
# F     90
# Name: reading pass, dtype: int64

# %%
study.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average math pass writing pass reading pass
# 0  72.666667         P            P            P
# ...

# %%
p=sns.countplot(x="parental level of education",data=study, hue="math pass")
_ =plt.setp(p.get_xticklabels(),rotation=90)

# %%
p= sns.countplot(x="test preparation course",data=study, hue="math pass")
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p= sns.countplot(x="test preparation course",data=study, hue="writing pass")
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p= sns.countplot(x="parental level of education",data=study, hue="writing pass")
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p= sns.countplot(x="parental level of education",data=study, hue="reading pass")
_=plt.setp(p.get_xticklabels(),rotation =90)

# %%
p= sns.countplot(x="test preparation course",data=study, hue="reading pass")
_=plt.setp(p.get_xticklabels(),rotation=90)
